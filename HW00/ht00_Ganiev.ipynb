# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

from scipy import stats

# %% [markdown]
# # Датасет

# %%
df = pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# # Анализ

# %% [markdown]
# Обратим внимание на некоторые числовые показатели:
#
# *   `Unit price` - цена за единицу товара
# *   `Rating` - рейтинг товара
#
# Средний рейтинг `Rating` - $6.97$, что достаточно близко к значению 50% квантиля, представляющего собой медиану выборки. Отдельно стоит проверить выборку рейтингов на нормальность.
#
# Средняя цена за единицу товара `Unit price` - $55.67$, что достаточно близко к значению 50% квантиля, представляющего собой медиану выборки.

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# 75%                   4.761905     22.445250     8.50000
# max                   4.761905     49.650000    10.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %% [markdown]
# # Очистка данных

# %% [markdown]
# ### Объединение даты и времени в один столбец и присвоение этому новому столбцу тип datetime

# %%
df["Datetime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

df.drop(["Date", "Time"], axis = 1, inplace = True)

# %% [markdown]
# # Предварительный анализ

# %%
sns.pairplot(df, corner = True)

# %%
sns.heatmap(df.drop("gross margin percentage", axis = 1).corr(numeric_only = True), annot = True, vmin = -1, vmax = 1, cmap = "coolwarm")

plt.title('Матрица корреляции')

plt.show()

# %%
keys = ['Rating', 'Unit price']

fig, axes = plt.subplots(ncols=len(keys))
fig.set_size_inches(8 * len(keys), 4)
axes = axes.flatten()

for key, ax in zip(keys, axes):
    ax.hist(df[key], density=True, bins=23)
    
    loc = df[key].mean()
    scale = df[key].std()
    
    x_left, x_right = ax.get_xlim()
    x = np.linspace(x_left, x_right, 10000)
    y = stats.norm.pdf(x, loc=loc, scale=scale)
    
    ax.plot(x, y, linestyle='dashed')
    ax.set_title(key)

# %%
for key in keys:
    print(key)
    
    samples = df[key]
    
    loc = samples.mean()
    scale = samples.std()

    for i in range(1, 4):
        true_value = stats.norm.cdf(i) - stats.norm.cdf(-i)
        sample_value = ((samples >= loc - i * scale) & (samples <= loc + i * scale)).sum() / samples.shape[0]
        
        print(f'{i} sigma(s)')
        print(f'\ttheoretical:\t{true_value}')
        print(f'\tsample:\t\t{sample_value}')
        
    print()
# Out:
# Rating
# 1 sigma(s)
# 	theoretical:	0.6826894921370859
# 	sample:		0.574
# 2 sigma(s)
# 	theoretical:	0.9544997361036416
# 	sample:		1.0
# 3 sigma(s)
# 	theoretical:	0.9973002039367398
# 	sample:		1.0
#
# Unit price
# 1 sigma(s)
# 	theoretical:	0.6826894921370859
# 	sample:		0.574
# 2 sigma(s)
# 	theoretical:	0.9544997361036416
# 	sample:		1.0
# 3 sigma(s)
# 	theoretical:	0.9973002039367398
# 	sample:		1.0

# %%
plt.scatter(df['Rating'], df['Unit price'])
plt.show()

# %% [markdown]
# ## Стастические показатели для выборок

# %% [markdown]
# Оценим нормальность выборок также  на основании известных характеристик нормального распределения. В частности:
# * Вероятность попасть в интервал от $\mu - \sigma$ до $\mu + \sigma$ равна $0.68$,
# * В интервал от $\mu - 2\sigma$ до $\mu + 2\sigma$ — $0.95$,
# * В интервал от $\mu - 3\sigma$ до $\mu + 3\sigma$ — $0.997$.
#
# Если рассчётные цифры оказываются близки к теоретическим, то распределения можно признать нормальными.
#
# На основании такой оценки `Rating` относится к нормальному распределению также, как `Unit price`.

# %%
def sum_of_squares(samples: np.ndarray) -> float:
    return ((samples - samples.mean()) ** 2).sum()

# %%
ones = np.ones((1000,1))
x_pot = np.hstack((ones, df['Rating'].values.reshape(1000,1)))

# %%
XTX = x_pot.T.dot(x_pot)
XTX_inv = np.linalg.inv(XTX)

b = XTX_inv.dot(x_pot.T).dot(df['Unit price'])
z = x_pot.dot(b)
e = df['Unit price'] - z

# %%
R = 1 - sum_of_squares(e) / sum_of_squares(np.array(df['Unit price']))
R
# Out:
# 7.704463265967298e-05

# %% [markdown]
# ## Верно ли, что оценка зависит от филиала?

# %% [markdown]
# Разделим нашу выборку на три части по филиалам A, B и C.
#
# Проведём дисперсионный анализ для средний значени оценок по выборке. Так как $F < t$, то можно точно сказать, что оценка не зависит от филиала.

# %%
def var_analise(df, df1, df2, f):
  all1 = df1.shape[0]
  all2 = df2.shape[0]
  res1_mean = df1[f].mean()
  res2_mean = df2[f].mean()
  res_mean = df[f].mean()
  SS_b = all1 * (res1_mean - res_mean) ** 2 + all2 * (res2_mean - res_mean) ** 2
  SS_w = ((df1[f] - res1_mean) ** 2).sum() + ((df2[f]- res2_mean) ** 2).sum()

  k = 2
  n = all1 + all2
  k1 = k - 1
  k2 = n - k
  sigma2_b = SS_b / k1
  sigma2_w = SS_w / k2
  sigma2_b, sigma2_w

  F = sigma2_b / sigma2_w

  alpha = 0.05

  t = stats.f.ppf(1 - alpha, k1, k2)

  return F>t

# %%
df1 = df[df['Branch'] == 'A']
df2 = df[df['Branch'] == 'B']
df3 = df[df['Branch'] == 'C']

# %%
var_analise(df, df1, df2, 'Rating')
# Out:
# False

# %%
var_analise(df, df1, df3, 'Rating')
# Out:
# False

# %%
var_analise(df, df2, df3, 'Rating')
# Out:
# False

# %% [markdown]
# ## Анализ

# %%
n = 1000
m = 1

k1 = m
k2 = n - m - 1

k1, k2
# Out:
# (1, 998)

# %%
alpha = 0.05

t = stats.f.ppf(1 - alpha, k1, k2)
t
# Out:
# 3.8507933707838875

# %%
F = (R / k1) / ((1 - R) / k2)
F
# Out:
# 0.07689646785447231

# %%
b1 = np.cov(df['Unit price'], df['Rating'], ddof=1)[0, 1] / np.var(df['Unit price'], ddof=1)
b0 = df['Rating'].mean() - b1 * df['Unit price'].mean()

# %%
plt.scatter(df['Rating'], df['Unit price'])
x = np.linspace(0, 10, 1000)
y = b0*x + b1
plt.plot(x, y, color = 'r')
plt.show()

# %% [markdown]
# ## Анализ поведения клиентов

# %% [markdown]
# ### Анализ популярности продуктовой линейки в разбивке по типу клиента и полу

# %%
customer_type_product_popularity = df.groupby(['Customer type', 'Product line'])['Quantity'].sum().reset_index()

customer_type_product_popularity
# Out:
#    Customer type            Product line  Quantity
# 0         Member  Electronic accessories       429
# 1         Member     Fashion accessories       439
# 2         Member      Food and beverages       506
# 3         Member       Health and beauty       428
# 4         Member      Home and lifestyle       490
# 5         Member       Sports and travel       493
# 6         Normal  Electronic accessories       542
# 7         Normal     Fashion accessories       463
# 8         Normal      Food and beverages       446
# 9         Normal       Health and beauty       426
# 10        Normal      Home and lifestyle       421
# 11        Normal       Sports and travel       427

# %%
customer_type_product_popularity.pivot_table(index = "Product line",columns = "Customer type",values = "Quantity",
).astype(int).style.background_gradient(cmap = "RdYlGn", axis = None)
# Out:
# <style type="text/css">
# #T_ecfd2_row0_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_ecfd2_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ecfd2_row1_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_ecfd2_row1_col1 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_ecfd2_row2_col0 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_ecfd2_row2_col1 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_ecfd2_row3_col0 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_ecfd2_row3_col1 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_ecfd2_row4_col0 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_ecfd2_row4_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ecfd2_row5_col0 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_ecfd2_row5_col1 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ecfd2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Customer type</th>
#       <th id="T_ecfd2_level0_col0" class="col_heading level0 col0" >Member</th>
#       <th id="T_ecfd2_level0_col1" class="col_heading level0 col1" >Normal</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product line</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecfd2_level0_row0" class="row_heading level0 row0" >Electronic accessories</th>
#       <td id="T_ecfd2_row0_col0" class="data row0 col0" >429</td>
#       <td id="T_ecfd2_row0_col1" class="data row0 col1" >542</td>
#     </tr>
#     <tr>
#       <th id="T_ecfd2_level0_row1" class="row_heading level0 row1" >Fashion accessories</th>
#       <td id="T_ecfd2_row1_col0" class="data row1 col0" >439</td>
#       <td id="T_ecfd2_row1_col1" class="data row1 col1" >463</td>
#     </tr>
#     <tr>
#       <th id="T_ecfd2_level0_row2" class="row_heading level0 row2" >Food and beverages</th>
#       <td id="T_ecfd2_row2_col0" class="data row2 col0" >506</td>
#       <td id="T_ecfd2_row2_col1" class="data row2 col1" >446</td>
#     </tr>
#     <tr>
#       <th id="T_ecfd2_level0_row3" class="row_heading level0 row3" >Health and beauty</th>
#       <td id="T_ecfd2_row3_col0" class="data row3 col0" >428</td>
#       <td id="T_ecfd2_row3_col1" class="data row3 col1" >426</td>
#     </tr>
#     <tr>
#       <th id="T_ecfd2_level0_row4" class="row_heading level0 row4" >Home and lifestyle</th>
#       <td id="T_ecfd2_row4_col0" class="data row4 col0" >490</td>
#       <td id="T_ecfd2_row4_col1" class="data row4 col1" >421</td>
#     </tr>
#     <tr>
#       <th id="T_ecfd2_level0_row5" class="row_heading level0 row5" >Sports and travel</th>
#       <td id="T_ecfd2_row5_col0" class="data row5 col0" >493</td>
#       <td id="T_ecfd2_row5_col1" class="data row5 col1" >427</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Product line', y='Quantity', hue='Customer type', data=customer_type_product_popularity)
plt.title('Популярность продуктовой линейки в зависимости от типа клиента')
plt.xticks(rotation=45)

plt.show()

# %%
gender_product_popularity = df.groupby(['Gender', 'Product line'])['Quantity'].sum().reset_index()

gender_product_popularity
# Out:
#     Gender            Product line  Quantity
# 0   Female  Electronic accessories       488
# 1   Female     Fashion accessories       530
# 2   Female      Food and beverages       514
# 3   Female       Health and beauty       343
# 4   Female      Home and lifestyle       498
# 5   Female       Sports and travel       496
# 6     Male  Electronic accessories       483
# 7     Male     Fashion accessories       372
# 8     Male      Food and beverages       438
# 9     Male       Health and beauty       511
# 10    Male      Home and lifestyle       413
# 11    Male       Sports and travel       424

# %%
gender_product_popularity.pivot_table(index = "Product line",columns = "Gender",values = "Quantity",
).astype(int).style.background_gradient(cmap = "RdYlGn")
# Out:
# <style type="text/css">
# #T_7484a_row0_col0 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_7484a_row0_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_7484a_row1_col0, #T_7484a_row3_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7484a_row1_col1, #T_7484a_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7484a_row2_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_7484a_row2_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_7484a_row4_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_7484a_row4_col1 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_7484a_row5_col0 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_7484a_row5_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# </style>
# <table id="T_7484a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th id="T_7484a_level0_col0" class="col_heading level0 col0" >Female</th>
#       <th id="T_7484a_level0_col1" class="col_heading level0 col1" >Male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product line</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7484a_level0_row0" class="row_heading level0 row0" >Electronic accessories</th>
#       <td id="T_7484a_row0_col0" class="data row0 col0" >488</td>
#       <td id="T_7484a_row0_col1" class="data row0 col1" >483</td>
#     </tr>
#     <tr>
#       <th id="T_7484a_level0_row1" class="row_heading level0 row1" >Fashion accessories</th>
#       <td id="T_7484a_row1_col0" class="data row1 col0" >530</td>
#       <td id="T_7484a_row1_col1" class="data row1 col1" >372</td>
#     </tr>
#     <tr>
#       <th id="T_7484a_level0_row2" class="row_heading level0 row2" >Food and beverages</th>
#       <td id="T_7484a_row2_col0" class="data row2 col0" >514</td>
#       <td id="T_7484a_row2_col1" class="data row2 col1" >438</td>
#     </tr>
#     <tr>
#       <th id="T_7484a_level0_row3" class="row_heading level0 row3" >Health and beauty</th>
#       <td id="T_7484a_row3_col0" class="data row3 col0" >343</td>
#       <td id="T_7484a_row3_col1" class="data row3 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_7484a_level0_row4" class="row_heading level0 row4" >Home and lifestyle</th>
#       <td id="T_7484a_row4_col0" class="data row4 col0" >498</td>
#       <td id="T_7484a_row4_col1" class="data row4 col1" >413</td>
#     </tr>
#     <tr>
#       <th id="T_7484a_level0_row5" class="row_heading level0 row5" >Sports and travel</th>
#       <td id="T_7484a_row5_col0" class="data row5 col0" >496</td>
#       <td id="T_7484a_row5_col1" class="data row5 col1" >424</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Product line', y='Quantity', hue='Gender', data=gender_product_popularity)
plt.title('Популярность продуктовой линейки в разбивке по полу')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Определение времени пиковых покупок по дням и часам

# %%
df = df.assign(Day = df['Datetime'].dt.day_name(), Hour = df['Datetime'].dt.hour)

# %%
sales_by_day = df.groupby('Day')['Total'].sum().reset_index().sort_values(by='Total', ascending=False)

sales_by_day
# Out:
#          Day       Total
# 2   Saturday  56120.8095
# 5    Tuesday  51482.2455
# 4   Thursday  45349.2480
# 3     Sunday  44457.8925
# 0     Friday  43926.3405
# 6  Wednesday  43731.1350
# 1     Monday  37899.0780

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Day', y='Total', data=sales_by_day, palette='viridis')
plt.title('Продажи по дням недели')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13232\2568236191.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Day', y='Total', data=sales_by_day, palette='viridis')

# %%
sales_by_hour = df.groupby('Hour')['Total'].sum().reset_index().sort_values(by='Hour', ascending=False)

sales_by_hour
# Out:
#     Hour       Total
# 10    20  22969.5270
# 9     19  39699.5130
# 8     18  26030.3400
# 7     17  24445.2180
# 6     16  25226.3235
# 5     15  31179.5085
# 4     14  30828.3990
# 3     13  34723.2270
# 2     12  26065.8825
# 1     11  30377.3295
# 0     10  31421.4810

# %%
plt.figure(figsize=(10,6))

sns.lineplot(x='Hour', y='Total', data=sales_by_hour)
plt.title('Продажи по часам дня')
plt.show()

# %% [markdown]
# ### Сочетание типа клиента, пола и времени для более глубокого понимания

# %%
customer_behavior_analysis = (df.groupby(['Customer type', 'Gender', 'Day', 'Hour'])['Total']
                              .sum().reset_index().sort_values(by='Total', ascending=False))

customer_behavior_analysis
# Out:
#     Customer type  Gender        Day  Hour      Total
# 179        Normal  Female   Saturday    19  4171.0200
# 58         Member  Female    Tuesday    15  3963.4350
# 62         Member  Female    Tuesday    19  3295.9605
# 191        Normal  Female   Thursday    10  3188.0730
# 144        Member    Male  Wednesday    15  3076.4055
# ..            ...     ...        ...   ...        ...
# 168        Normal  Female     Monday    18    49.7700
# 294        Normal    Male  Wednesday    16    44.5935
# 154        Normal  Female     Friday    15    41.3910
# 290        Normal    Male  Wednesday    12    32.1405
# 75         Member    Male     Friday    11    20.6850
#
# [299 rows x 5 columns]

# %%
customer_behavior = customer_behavior_analysis.pivot_table(index="Day",columns="Hour",values="Total"
                                     ).style.format("{:.2f}").background_gradient(cmap="RdYlGn", axis=None)
customer_behavior
# Out:
# <style type="text/css">
# #T_1a33f_row0_col0 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_1a33f_row0_col1 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_1a33f_row0_col2 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_1a33f_row0_col3 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_1a33f_row0_col4 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_1a33f_row0_col5, #T_1a33f_row6_col10 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_1a33f_row0_col6 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_1a33f_row0_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1a33f_row0_col8, #T_1a33f_row6_col0 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_1a33f_row0_col9, #T_1a33f_row2_col1, #T_1a33f_row4_col4 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_1a33f_row0_col10, #T_1a33f_row6_col7 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_1a33f_row1_col0, #T_1a33f_row5_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_1a33f_row1_col1 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_1a33f_row1_col2, #T_1a33f_row3_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_1a33f_row1_col3 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_1a33f_row1_col4 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_1a33f_row1_col5 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_1a33f_row1_col6 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_1a33f_row1_col7, #T_1a33f_row6_col8 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_1a33f_row1_col8 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_1a33f_row1_col9, #T_1a33f_row4_col3 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_1a33f_row1_col10 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_1a33f_row2_col0 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_1a33f_row2_col2 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_1a33f_row2_col3 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_1a33f_row2_col4 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_1a33f_row2_col5 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_1a33f_row2_col6, #T_1a33f_row5_col6 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_1a33f_row2_col7 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_1a33f_row2_col8, #T_1a33f_row6_col3 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_1a33f_row2_col9 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_1a33f_row2_col10, #T_1a33f_row3_col10, #T_1a33f_row4_col9 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_1a33f_row3_col0 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_1a33f_row3_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_1a33f_row3_col3 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_1a33f_row3_col4 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_1a33f_row3_col5 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_1a33f_row3_col6 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_1a33f_row3_col7, #T_1a33f_row6_col9 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_1a33f_row3_col8 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_1a33f_row3_col9 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_1a33f_row4_col0 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_1a33f_row4_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_1a33f_row4_col2 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_1a33f_row4_col5 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_1a33f_row4_col6 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_1a33f_row4_col7 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_1a33f_row4_col8 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_1a33f_row4_col10 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_1a33f_row5_col0 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_1a33f_row5_col1 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_1a33f_row5_col3 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_1a33f_row5_col4 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_1a33f_row5_col5 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_1a33f_row5_col7 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_1a33f_row5_col8 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_1a33f_row5_col9 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1a33f_row5_col10 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_1a33f_row6_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_1a33f_row6_col2 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_1a33f_row6_col4, #T_1a33f_row6_col6 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_1a33f_row6_col5 {
#   background-color: #fee18d;
#   color: #000000;
# }
# </style>
# <table id="T_1a33f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Hour</th>
#       <th id="T_1a33f_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_1a33f_level0_col1" class="col_heading level0 col1" >11</th>
#       <th id="T_1a33f_level0_col2" class="col_heading level0 col2" >12</th>
#       <th id="T_1a33f_level0_col3" class="col_heading level0 col3" >13</th>
#       <th id="T_1a33f_level0_col4" class="col_heading level0 col4" >14</th>
#       <th id="T_1a33f_level0_col5" class="col_heading level0 col5" >15</th>
#       <th id="T_1a33f_level0_col6" class="col_heading level0 col6" >16</th>
#       <th id="T_1a33f_level0_col7" class="col_heading level0 col7" >17</th>
#       <th id="T_1a33f_level0_col8" class="col_heading level0 col8" >18</th>
#       <th id="T_1a33f_level0_col9" class="col_heading level0 col9" >19</th>
#       <th id="T_1a33f_level0_col10" class="col_heading level0 col10" >20</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a33f_level0_row0" class="row_heading level0 row0" >Friday</th>
#       <td id="T_1a33f_row0_col0" class="data row0 col0" >1417.92</td>
#       <td id="T_1a33f_row0_col1" class="data row0 col1" >662.32</td>
#       <td id="T_1a33f_row0_col2" class="data row0 col2" >539.81</td>
#       <td id="T_1a33f_row0_col3" class="data row0 col3" >1706.08</td>
#       <td id="T_1a33f_row0_col4" class="data row0 col4" >1722.09</td>
#       <td id="T_1a33f_row0_col5" class="data row0 col5" >924.02</td>
#       <td id="T_1a33f_row0_col6" class="data row0 col6" >773.09</td>
#       <td id="T_1a33f_row0_col7" class="data row0 col7" >473.35</td>
#       <td id="T_1a33f_row0_col8" class="data row0 col8" >793.82</td>
#       <td id="T_1a33f_row0_col9" class="data row0 col9" >1368.98</td>
#       <td id="T_1a33f_row0_col10" class="data row0 col10" >1030.62</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level0_row1" class="row_heading level0 row1" >Monday</th>
#       <td id="T_1a33f_row1_col0" class="data row1 col0" >934.60</td>
#       <td id="T_1a33f_row1_col1" class="data row1 col1" >718.16</td>
#       <td id="T_1a33f_row1_col2" class="data row1 col2" >1181.53</td>
#       <td id="T_1a33f_row1_col3" class="data row1 col3" >939.66</td>
#       <td id="T_1a33f_row1_col4" class="data row1 col4" >501.09</td>
#       <td id="T_1a33f_row1_col5" class="data row1 col5" >1285.34</td>
#       <td id="T_1a33f_row1_col6" class="data row1 col6" >1172.75</td>
#       <td id="T_1a33f_row1_col7" class="data row1 col7" >1059.75</td>
#       <td id="T_1a33f_row1_col8" class="data row1 col8" >701.52</td>
#       <td id="T_1a33f_row1_col9" class="data row1 col9" >649.66</td>
#       <td id="T_1a33f_row1_col10" class="data row1 col10" >595.66</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level0_row2" class="row_heading level0 row2" >Saturday</th>
#       <td id="T_

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=customer_behavior_analysis, x="Day", y="Total", hue="Hour", palette='flare')
# Out:
# <Axes: xlabel='Day', ylabel='Total'>

# %% [markdown]
# ## Эффективность работы филиала

# %% [markdown]
# ### Показатели продаж в разбивке по филиалам

# %%
sales_per_branch = df.groupby('Branch')['Total'].sum().reset_index().sort_values(by='Total', ascending=False)

sales_per_branch
# Out:
#   Branch        Total
# 2      C  110568.7065
# 0      A  106200.3705
# 1      B  106197.6720

# %%
plt.figure(figsize=(5, 3))

sns.barplot(x='Branch', y='Total', data=sales_per_branch)
plt.title('Общий объем продаж в филиале')
plt.show()

# %% [markdown]
# ### Удовлетворенность клиентов (рейтинг) в разбивке по отраслям

# %%
ratings_per_branch = df.groupby('Branch')['Rating'].mean().reset_index().sort_values(by='Rating', ascending=False)

ratings_per_branch
# Out:
#   Branch    Rating
# 2      C  7.072866
# 0      A  7.027059
# 1      B  6.818072

# %%
plt.figure(figsize=(5, 3))

sns.barplot(x='Branch', y='Rating', data=ratings_per_branch)
plt.title('Средний рейтинг по филиалу')
plt.show()

# %% [markdown]
# ### Сравнение валового дохода по отраслям

# %%
gross_income_per_branch = (df.groupby('Branch')['gross income']
                           .sum().reset_index().sort_values(by='gross income', ascending=False))
gross_income_per_branch
# Out:
#   Branch  gross income
# 2      C     5265.1765
# 0      A     5057.1605
# 1      B     5057.0320

# %%
plt.figure(figsize=(5, 3))

sns.barplot(x='Branch', y='gross income', data=gross_income_per_branch)
plt.title('Общий валовой доход по филиалу')
plt.show()

# %% [markdown]
# ### Объединение данных о продажах, рейтингах и валовом доходе для получения полного представления

# %%
branch_performance = pd.merge(sales_per_branch, ratings_per_branch, on='Branch')
branch_performance = pd.merge(branch_performance, gross_income_per_branch, on='Branch')

branch_performance.columns = ['Branch', 'Total Sales', 'Average Rating', 'Total Gross Income']
branch_performance = branch_performance.sort_values(by='Total Sales', ascending=False)
branch_performance
# Out:
#   Branch  Total Sales  Average Rating  Total Gross Income
# 0      C  110568.7065        7.072866           5265.1765
# 1      A  106200.3705        7.027059           5057.1605
# 2      B  106197.6720        6.818072           5057.0320

# %% [markdown]
# ### Зависимость показателей от линейки продуктов и типа клиента

# %% [markdown]
# #### Продажи по продуктовым линейкам для каждого филиала

# %%
product_sales_per_branch = (df.groupby(['Branch', 'Product line'])['Total']
                            .sum().reset_index().sort_values(by=['Branch', 'Total'], ascending=False))

product_sales_per_branch
# Out:
#    Branch            Product line       Total
# 14      C      Food and beverages  23766.8550
# 13      C     Fashion accessories  21560.0700
# 12      C  Electronic accessories  18968.9745
# 15      C       Health and beauty  16615.3260
# 17      C       Sports and travel  15761.9280
# 16      C      Home and lifestyle  13895.5530
# 11      B       Sports and travel  19988.1990
# 9       B       Health and beauty  19980.6600
# 10      B      Home and lifestyle  17549.1645
# 6       B  Electronic accessories  17051.4435
# 7       B     Fashion accessories  16413.3165
# 8       B      Food and beverages  15214.8885
# 4       A      Home and lifestyle  22417.1955
# 5       A       Sports and travel  19372.6995
# 0       A  Electronic accessories  18317.1135
# 2       A      Food and beverages  17163.1005
# 1       A     Fashion accessories  16332.5085
# 3       A       Health and beauty  12597.7530

# %%
product_sales_per_branch.pivot_table(index="Product line",columns="Branch",values="Total"
                                     ).style.format("{:.2f}").background_gradient(cmap="RdYlGn", axis=None)
# Out:
# <style type="text/css">
# #T_83c8e_row0_col0 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_83c8e_row0_col1 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_83c8e_row0_col2 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_83c8e_row1_col0 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_83c8e_row1_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_83c8e_row1_col2 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_83c8e_row2_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_83c8e_row2_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_83c8e_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_83c8e_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_83c8e_row3_col1, #T_83c8e_row5_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_83c8e_row3_col2 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_83c8e_row4_col0 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_83c8e_row4_col1 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_83c8e_row4_col2 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_83c8e_row5_col0 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_83c8e_row5_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# </style>
# <table id="T_83c8e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Branch</th>
#       <th id="T_83c8e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_83c8e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_83c8e_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product line</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83c8e_level0_row0" class="row_heading level0 row0" >Electronic accessories</th>
#       <td id="T_83c8e_row0_col0" class="data row0 col0" >18317.11</td>
#       <td id="T_83c8e_row0_col1" class="data row0 col1" >17051.44</td>
#       <td id="T_83c8e_row0_col2" class="data row0 col2" >18968.97</td>
#     </tr>
#     <tr>
#       <th id="T_83c8e_level0_row1" class="row_heading level0 row1" >Fashion accessories</th>
#       <td id="T_83c8e_row1_col0" class="data row1 col0" >16332.51</td>
#       <td id="T_83c8e_row1_col1" class="data row1 col1" >16413.32</td>
#       <td id="T_83c8e_row1_col2" class="data row1 col2" >21560.07</td>
#     </tr>
#     <tr>
#       <th id="T_83c8e_level0_row2" class="row_heading level0 row2" >Food and beverages</th>
#       <td id="T_83c8e_row2_col0" class="data row2 col0" >17163.10</td>
#       <td id="T_83c8e_row2_col1" class="data row2 col1" >15214.89</td>
#       <td id="T_83c8e_row2_col2" class="data row2 col2" >23766.85</td>
#     </tr>
#     <tr>
#       <th id="T_83c8e_level0_row3" class="row_heading level0 row3" >Health and beauty</th>
#       <td id="T_83c8e_row3_col0" class="data row3 col0" >12597.75</td>
#       <td id="T_83c8e_row3_col1" class="data row3 col1" >19980.66</td>
#       <td id="T_83c8e_row3_col2" class="data row3 col2" >16615.33</td>
#     </tr>
#     <tr>
#       <th id="T_83c8e_level0_row4" class="row_heading level0 row4" >Home and lifestyle</th>
#       <td id="T_83c8e_row4_col0" class="data row4 col0" >22417.20</td>
#       <td id="T_83c8e_row4_col1" class="data row4 col1" >17549.16</td>
#       <td id="T_83c8e_row4_col2" class="data row4 col2" >13895.55</td>
#     </tr>
#     <tr>
#       <th id="T_83c8e_level0_row5" class="row_heading level0 row5" >Sports and travel</th>
#       <td id="T_83c8e_row5_col0" class="data row5 col0" >19372.70</td>
#       <td id="T_83c8e_row5_col1" class="data row5 col1" >19988.20</td>
#       <td id="T_83c8e_row5_col2" class="data row5 col2" >15761.93</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,6))

sns.barplot(x='Branch', y='Total', hue='Product line', data=product_sales_per_branch)

plt.title('Общий объем продаж по каждой продуктовой линейке в разбивке по филиалам')
plt.ylabel('Total Sales')
plt.xlabel('Branch')
plt.legend(title='Product Line', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Сравнение в зависимости от типа клиента

# %%
customer_type_sales_per_branch = (df.groupby(['Branch', 'Customer type'])['Total'].sum().reset_index()
                                  .sort_values(by=['Branch', 'Total'], ascending=False))

customer_type_sales_per_branch
# Out:
#   Branch Customer type       Total
# 4      C        Member  56881.2825
# 5      C        Normal  53687.4240
# 2      B        Member  53704.6860
# 3      B        Normal  52492.9860
# 0      A        Member  53637.4755
# 1      A        Normal  52562.8950

# %%
customer_type_sales_per_branch.pivot_table(index = "Customer type",columns = "Branch",values = "Total",
).style.format("{:.2f}").background_gradient(cmap = "RdYlGn", axis = None)
# Out:
# <style type="text/css">
# #T_dfb57_row0_col0 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_dfb57_row0_col1 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_dfb57_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_dfb57_row1_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_dfb57_row1_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_dfb57_row1_col2 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# </style>
# <table id="T_dfb57">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Branch</th>
#       <th id="T_dfb57_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_dfb57_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_dfb57_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Customer type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfb57_level0_row0" class="row_heading level0 row0" >Member</th>
#       <td id="T_dfb57_row0_col0" class="data row0 col0" >53637.48</td>
#       <td id="T_dfb57_row0_col1" class="data row0 col1" >53704.69</td>
#       <td id="T_dfb57_row0_col2" class="data row0 col2" >56881.28</td>
#     </tr>
#     <tr>
#       <th id="T_dfb57_level0_row1" class="row_heading level0 row1" >Normal</th>
#       <td id="T_dfb57_row1_col0" class="data row1 col0" >52562.89</td>
#       <td id="T_dfb57_row1_col1" class="data row1 col1" >52492.99</td>
#       <td id="T_dfb57_row1_col2" class="data row1 col2" >53687.42</td>
#     </tr>
#   </tbody>
# </table>

# %%
customer_type_pivot = customer_type_sales_per_branch.pivot(index='Branch', columns='Customer type', values='Total')

customer_type_pivot.plot(kind='bar', figsize=(10,6))

plt.title('Общий объем продаж в разбивке по типам клиентов в каждом филиале')
plt.ylabel('Total Sales')
plt.xlabel('Branch')
plt.legend(title='Customer Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Удовлетворенность клиентов

# %% [markdown]
# ### Классификация оценок клиентов по категориям

# %%
df = df.assign(Satisfaction_Level = np.where(df["Rating"] <= 4, "Low", 
np.where((df["Rating"] >= 5) & (df["Rating"] <= 7), "Medium", "High"))
).rename(columns = {"Satisfaction_Level": "Satisfaction Level"})

df[['Rating', 'Satisfaction Level']]
# Out:
#      Rating Satisfaction Level
# 0       9.1               High
# 1       9.6               High
# 2       7.4               High
# 3       8.4               High
# 4       5.3             Medium
# ..      ...                ...
# 995     6.2             Medium
# 996     4.4               High
# 997     7.7               High
# 998     4.1               High
# 999     6.6             Medium
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Изучение взаимосвязей между показателями и рейтингами

# %% [markdown]
# #### Линия продуктов и уровень удовлетворенности

# %%
product_line_satisfaction = df.groupby(['Product line', 'Satisfaction Level'])['Invoice ID'].count().reset_index()

product_line_satisfaction.rename(columns={'Invoice ID': 'Count'}, inplace=True)
product_line_satisfaction = product_line_satisfaction.sort_values(by='Count', ascending=False)

product_line_satisfaction
# Out:
#               Product line Satisfaction Level  Count
# 6       Food and beverages               High    113
# 3      Fashion accessories               High    111
# 12      Home and lifestyle               High    106
# 0   Electronic accessories               High    103
# 9        Health and beauty               High    100
# 14       Sports and travel               High     90
# 16       Sports and travel             Medium     75
# 2   Electronic accessories             Medium     66
# 5      Fashion accessories             Medium     65
# 8       Food and beverages             Medium     57
# 13      Home and lifestyle             Medium     54
# 11       Health and beauty             Medium     49
# 7       Food and beverages                Low      4
# 10       Health and beauty                Low      3
# 4      Fashion accessories                Low      2
# 1   Electronic accessories                Low      1
# 15       Sports and travel                Low      1

# %%
product_line_satisfaction.pivot_table(index = "Product line",columns = "Satisfaction Level",values = "Count",
).replace(np.NAN, 0).style.format("{:.0f}").background_gradient(cmap="RdYlGn", axis=None)
# Out:
# <style type="text/css">
# #T_6bfae_row0_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_6bfae_row0_col1, #T_6bfae_row5_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_6bfae_row0_col2 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_6bfae_row1_col0 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_6bfae_row1_col1 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_6bfae_row1_col2 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_6bfae_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6bfae_row2_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_6bfae_row2_col2 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_6bfae_row3_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_6bfae_row3_col1 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_6bfae_row3_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_6bfae_row4_col0 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_6bfae_row4_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6bfae_row4_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_6bfae_row5_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_6bfae_row5_col2 {
#   background-color: #b9e176;
#   color: #000000;
# }
# </style>
# <table id="T_6bfae">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Satisfaction Level</th>
#       <th id="T_6bfae_level0_col0" class="col_heading level0 col0" >High</th>
#       <th id="T_6bfae_level0_col1" class="col_heading level0 col1" >Low</th>
#       <th id="T_6bfae_level0_col2" class="col_heading level0 col2" >Medium</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product line</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bfae_level0_row0" class="row_heading level0 row0" >Electronic accessories</th>
#       <td id="T_6bfae_row0_col0" class="data row0 col0" >103</td>
#       <td id="T_6bfae_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_6bfae_row0_col2" class="data row0 col2" >66</td>
#     </tr>
#     <tr>
#       <th id="T_6bfae_level0_row1" class="row_heading level0 row1" >Fashion accessories</th>
#       <td id="T_6bfae_row1_col0" class="data row1 col0" >111</td>
#       <td id="T_6bfae_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_6bfae_row1_col2" class="data row1 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_6bfae_level0_row2" class="row_heading level0 row2" >Food and beverages</th>
#       <td id="T_6bfae_row2_col0" class="data row2 col0" >113</td>
#       <td id="T_6bfae_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_6bfae_row2_col2" class="data row2 col2" >57</td>
#     </tr>
#     <tr>
#       <th id="T_6bfae_level0_row3" class="row_heading level0 row3" >Health and beauty</th>
#       <td id="T_6bfae_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_6bfae_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_6bfae_row3_col2" class="data row3 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_6bfae_level0_row4" class="row_heading level0 row4" >Home and lifestyle</th>
#       <td id="T_6bfae_row4_col0" class="data row4 col0" >106</td>
#       <td id="T_6bfae_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_6bfae_row4_col2" class="data row4 col2" >54</td>
#     </tr>
#     <tr>
#       <th id="T_6bfae_level0_row5" class="row_heading level0 row5" >Sports and travel</th>
#       <td id="T_6bfae_row5_col0" class="data row5 col0" >90</td>
#       <td id="T_6bfae_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_6bfae_row5_col2" class="data row5 col2" >75</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,6))

sns.barplot(x='Product line', y='Count', hue='Satisfaction Level', data=product_line_satisfaction)
plt.title('Уровни удовлетворенности клиентов в разбивке по продуктовым линейкам')
plt.ylabel('Number of Ratings')
plt.xlabel('Product Line')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Способ оплаты и уровень удовлетворенности

# %%
payment_satisfaction = df.groupby(['Payment', 'Satisfaction Level'])['Invoice ID'].count().reset_index()

payment_satisfaction.rename(columns={'Invoice ID': 'Count'}, inplace=True)
payment_satisfaction = payment_satisfaction.sort_values(by='Count', ascending=False)

payment_satisfaction
# Out:
#        Payment Satisfaction Level  Count
# 6      Ewallet               High    212
# 0         Cash               High    209
# 3  Credit card               High    202
# 2         Cash             Medium    133
# 8      Ewallet             Medium    129
# 5  Credit card             Medium    104
# 4  Credit card                Low      5
# 7      Ewallet                Low      4
# 1         Cash                Low      2

# %%
payment_satisfaction.pivot_table(index = "Payment",columns = "Satisfaction Level",values = "Count",

).style.format("{:.0f}").background_gradient(cmap="RdYlGn", axis=None)
# Out:
# <style type="text/css">
# #T_70cf6_row0_col0 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_70cf6_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_70cf6_row0_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_70cf6_row1_col0 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_70cf6_row1_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_70cf6_row1_col2 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_70cf6_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_70cf6_row2_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_70cf6_row2_col2 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# </style>
# <table id="T_70cf6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Satisfaction Level</th>
#       <th id="T_70cf6_level0_col0" class="col_heading level0 col0" >High</th>
#       <th id="T_70cf6_level0_col1" class="col_heading level0 col1" >Low</th>
#       <th id="T_70cf6_level0_col2" class="col_heading level0 col2" >Medium</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Payment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70cf6_level0_row0" class="row_heading level0 row0" >Cash</th>
#       <td id="T_70cf6_row0_col0" class="data row0 col0" >209</td>
#       <td id="T_70cf6_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_70cf6_row0_col2" class="data row0 col2" >133</td>
#     </tr>
#     <tr>
#       <th id="T_70cf6_level0_row1" class="row_heading level0 row1" >Credit card</th>
#       <td id="T_70cf6_row1_col0" class="data row1 col0" >202</td>
#       <td id="T_70cf6_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_70cf6_row1_col2" class="data row1 col2" >104</td>
#     </tr>
#     <tr>
#       <th id="T_70cf6_level0_row2" class="row_heading level0 row2" >Ewallet</th>
#       <td id="T_70cf6_row2_col0" class="data row2 col0" >212</td>
#       <td id="T_70cf6_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_70cf6_row2_col2" class="data row2 col2" >129</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Payment', y='Count', hue='Satisfaction Level', data=payment_satisfaction)
plt.title('Уровни удовлетворенности клиентов в зависимости от способа оплаты')
plt.ylabel('Number of Ratings')
plt.xlabel('Payment Method')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Анализ по продуктам

# %% [markdown]
# ### Анализ объема продаж по продуктовым линейкам

# %%
product_sales_volume = df.groupby('Product line')['Quantity'].sum().sort_values(ascending=False).reset_index()

product_sales_volume
# Out:
#              Product line  Quantity
# 0  Electronic accessories       971
# 1      Food and beverages       952
# 2       Sports and travel       920
# 3      Home and lifestyle       911
# 4     Fashion accessories       902
# 5       Health and beauty       854

# %%
plt.figure(figsize=(10,6))

sns.barplot(data = product_sales_volume, x="Product line", y="Quantity", palette='viridis')
plt.title('Общий объем продаж по продуктовым линейкам')
plt.xlabel('Product Line')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13232\1713687069.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = product_sales_volume, x="Product line", y="Quantity", palette='viridis')

# %% [markdown]
# ### Валовой доход в разбивке по продуктовым линейкам

# %%
product_gross_income = df.groupby('Product line')['gross income'].sum().sort_values(ascending=False).reset_index()

product_gross_income
# Out:
#              Product line  gross income
# 0      Food and beverages     2673.5640
# 1       Sports and travel     2624.8965
# 2  Electronic accessories     2587.5015
# 3     Fashion accessories     2585.9950
# 4      Home and lifestyle     2564.8530
# 5       Health and beauty     2342.5590

# %%
plt.figure(figsize=(10,6))

sns.barplot(data = product_gross_income, x="Product line", y="gross income", palette='viridis')
plt.title('Общий валовой доход по продуктовым линейкам')
plt.xlabel('Product Line')
plt.ylabel('Total Gross Income')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13232\4048497081.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = product_gross_income, x="Product line", y="gross income", palette='viridis')

# %% [markdown]
# ### Средний валовой доход в разбивке по продуктовым линейкам

# %%
avg_gross_income_per_sale = df.groupby('Product line')['gross income'].mean().sort_values(ascending=False).reset_index()

avg_gross_income_per_sale
# Out:
#              Product line  gross income
# 0      Home and lifestyle     16.030331
# 1       Sports and travel     15.812630
# 2       Health and beauty     15.411572
# 3      Food and beverages     15.365310
# 4  Electronic accessories     15.220597
# 5     Fashion accessories     14.528062

# %%
plt.figure(figsize=(10,6))

sns.barplot(data = avg_gross_income_per_sale, x="Product line", y="gross income", palette='viridis')
plt.title('Средний валовой доход в разбивке по продуктовым линейкам')
plt.xlabel('Product Line')
plt.ylabel('Average Gross Income')
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13232\1544904092.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = avg_gross_income_per_sale, x="Product line", y="gross income", palette='viridis')

# %% [markdown]
# ### Корреляция между объемом продаж и валовым доходом

# %%
product_analysis = df.groupby('Product line').agg({'Quantity': 'sum', 'gross income': 'sum'}).reset_index()

product_analysis
# Out:
#              Product line  Quantity  gross income
# 0  Electronic accessories       971     2587.5015
# 1     Fashion accessories       902     2585.9950
# 2      Food and beverages       952     2673.5640
# 3       Health and beauty       854     2342.5590
# 4      Home and lifestyle       911     2564.8530
# 5       Sports and travel       920     2624.8965

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(data=product_analysis, x='Quantity', y='gross income', hue="Product line", s = 100)
plt.title('Соотношение объема продаж к валовому доходу в разбивке по продуктовым линейкам')
plt.xlabel('Total Sales Volume')
plt.ylabel('Total Gross Income')
plt.legend(title='Product Line', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# ### Сравнение продуктовой линейки по типу клиента

# %%
product_customer_analysis = df.groupby(['Product line', 'Customer type']).agg({'Quantity': 'sum', 'gross income': 'sum'}).unstack()

product_customer_analysis
# Out:
#                        Quantity        gross income
# Customer type            Member Normal       Member     Normal
# Product line
# Electronic accessories      429    542    1166.5950  1420.9065
# Fashion accessories         439    463    1253.5220  1332.4730
# Food and beverages          506    446    1493.2200  1180.3440
# Health and beauty           428    426    1230.0495  1112.5095
# Home and lifestyle          490    421    1332.2870  1232.5660
# Sports and travel           493    427    1344.4905  1280.4060

# %%
product_customer_analysis['Quantity'].plot(kind='bar', figsize=(10,6))

plt.title('Объем продаж в разбивке по продуктовой линейке и типу клиентов')
plt.ylabel('Total Sales Volume')
plt.xticks(rotation=45)
plt.legend(title='Customer Type')
plt.show()

product_customer_analysis['gross income'].plot(kind='bar', figsize=(10,6), color=['#FFA07A', '#20B2AA'])

plt.title('Валовой доход в разбивке по продуктовой линейке и типу клиентов')
plt.ylabel('Total Gross Income')
plt.xticks(rotation=45)
plt.legend(title='Customer Type')
plt.show()

# %% [markdown]
# ### Выводы

# %% [markdown]
# 1. Суббота - самый прибыльный день для магазина.
# 2. Женщины покупают больше косметических товаров, когда мужчины больше товаров, относящихся к здоровью.
# 3. Больше всего прибыли идет под конец рабочего дня магазинов.
# 4. Филиалы почти не различаются по выручке.
